# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Flower shipment.csv")

# %%
df.head()      # first 5 rows
# Out:
#    id  Order number      Date   Plant family             Placement  \
# 0   1          1619  07/12/18     Asteraceae     71 Rutledge Place
# 1   2          1556  06/27/18     Solanaceae  0290 Florence Avenue
# 2   3          1219  10/20/18       Fagaceae    8 Fairfield Street
# 3   4          1012  06/18/18       Fabaceae    4100 Swallow Point
# 4   5          1989  08/07/18  Saxifragaceae      785 Waubesa Park
#
#           Phone      Color    Cost
# 0  982-480-5919      Khaki  $5.09
# 1  262-509-4907     Yellow  $7.90
# 2  234-838-6235       Puce  $9.77
# 3  256-551-8984  Turquoise  $7.60
# 4  154-491-0827       Pink  $6.14

# %%
df.tail()      # last 5 rows
# Out:
#       id  Order number      Date    Plant family               Placement  \
# 670  671          1580  06/06/18     Primulaceae       3 Darwin Junction
# 671  672          2441  07/15/18      Leskeaceae         28 Warbler Road
# 672  673          2637  05/12/18        Rutaceae  2473 Valley Edge Drive
# 673  674          1248  07/28/18  Pertusariaceae      23 Farmco Crossing
# 674  675          2122  07/05/18      Asteraceae           32 Roth Point
#
#             Phone      Color    Cost
# 670  143-489-0146  Turquoise  $5.88
# 671  701-941-4375       Blue  $6.89
# 672  910-950-2932       Teal  $5.32
# 673  533-406-5922     Purple  $7.47
# 674  475-892-9615       Pink  $8.87

# %%
df.shape       # rows & columns
# Out:
# (675, 8)

# %%
df.columns     # column names
# Out:
# Index(['id', 'Order number', 'Date', 'Plant family', 'Placement', 'Phone',
#        'Color', 'Cost'],
#       dtype='object')

# %%
df.info()              # data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            675 non-null    int64
#  1   Order number  675 non-null    int64
#  2   Date          675 non-null    object
#  3   Plant family  675 non-null    object
#  4   Placement     675 non-null    object
#  5   Phone         675 non-null    object
#  6   Color         675 non-null    object
#  7   Cost          675 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 42.3+ KB

# %%
df.isnull().sum()     # missing values
# Out:
# id              0
# Order number    0
# Date            0
# Plant family    0
# Placement       0
# Phone           0
# Color           0
# Cost            0
# dtype: int64

# %%
df.describe()         # statistics
# Out:
#           id  Order number
# count  675.0    675.000000
# mean   338.0   1997.785185
# std    195.0    590.064700
# min      1.0   1001.000000
# 25%    169.5   1477.500000
# 50%    338.0   2036.000000
# 75%    506.5   2519.000000
# max    675.0   2999.000000

# %%
df = df.dropna() #removes missing values

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
df.to_csv("cleaned_flower_data.csv", index=False)
